# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdooStore/Word_Teacher/blob/main/Mini_Translate_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python -m textblob.download_corpora

# %%
from textblob import Word

print("👋 Hello! I'm the Word Teacher.")
print("Type ONE word, and I will analyze it with NLP!")
print("______________________________________________")

while True:
  user_word = input("\nEnter a word (or 'quit' to stop): ").lower()
  if user_word == 'quit':
    print("Bye! 👋")
    break

  w =Word(user_word)

  corrected = w.spellcheck()[0][0]

  lemma = Word(corrected).lemmatize('v')

  print(f"\n🔎 NLP Analysis for '{user_word}':")
  print(f"✅ Corrected spelling: {corrected}")
  print(f"🌱 Lemma (base form): {lemma}")
